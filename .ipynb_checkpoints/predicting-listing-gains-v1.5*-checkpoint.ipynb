# %% [markdown]
# # TensorFlow Functional API Model for Listing-Gain Prediction in Indian IPOs

# %% [markdown]
# ## Table of Contents
#
# 1. [Introduction](#Introduction)
# 2. [Loading and Examining the Data](#Loading-and-Examining-the-Data)
#    - [Dataset Overview](#Dataset-Overview)
# 3. [Exploratory Data Analysis](#Exploratory-Data-Analysis)
#    - [Data Quality and Outlier Analysis](#Data-Quality-and-Outlier-Analysis)
#    - [Distribution of Numerical Features](#Distribution-of-Numerical-Features)
#    - [Correlation Analysis](#Correlation-Analysis)
# 4. [Data Preprocessing and Feature Engineering](#Data-Preprocessing-and-Feature-Engineering)
# 5. [Feature Selection](#Feature-Selection)
# 6. [Building a Deep Learning Model](#Building-a-Deep-Learning-Model)
# 7. [Model Evaluation](#Model-Evaluation)
# 8. [Conclusion](#Conclusion)

# %% [markdown]
# ## Introduction
#
# This project aims to build a TensorFlow (Keras) **Functional API** model to predict **listing gains** for Indian IPOs. The goal is twofold: (1) rank IPOs by probability of a positive first-day return and (2) select a clear decision threshold for “Profit” vs “No Profit.” The dataset is split **stratified** into Train/Val/Test (204/51/64), and results are reported on the hold-out test set.
#
# I use a compact MLP (7 inputs → Dense(16) → BN → Dropout → Dense(8) → BN → Dropout → Sigmoid; ~369 params) trained with **Adam**, **EarlyStopping** on validation AUC, and **ReduceLROnPlateau**. Reproducibility is enforced via fixed seeds and deterministic training (no shuffling). The classification threshold is chosen on the validation set by **maximizing F1**.
#
# Key outcomes: **Validation ROC-AUC 0.744** and **PR-AUC 0.773**; best validation F1 at **threshold = 0.32**. On the test set, **ROC-AUC = 0.725**. Using the F1-selected threshold, the model emphasizes recall for profitable IPOs (**recall ≈ 0.914**, **precision ≈ 0.627**), yielding overall accuracy **≈ 0.656**.

# %% [markdown]
# ## Loading and Examining the Data

# %%
# Import required libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import skew, kurtosis
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
# Import required libraries
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"
import tensorflow as tf
from tensorflow.keras import layers, regularizers, Model, Input
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.metrics import AUC, Precision, Recall
from sklearn.model_selection import StratifiedShuffleSplit
import numpy as np
from sklearn.metrics import (
    roc_auc_score, roc_curve,
    precision_recall_curve, auc,
    f1_score, confusion_matrix, classification_report
)

# Jupyter magic
# %matplotlib inline

pd.set_option("display.float_format", lambda x: f"{x:,.3f}")

# Set visual style
sns.set_style("dark")
sns.set_palette("husl")
plt.style.use('seaborn-v0_8')
plt.rcParams["axes.facecolor"] = "#FDFFE2"
plt.rcParams["figure.facecolor"] = "#FDFFE2"
plt.rcParams["axes.edgecolor"] = "#FDFFE2"
plt.rcParams["xtick.labelsize"] = 14
plt.rcParams["ytick.labelsize"] = 14
plt.rcParams["axes.titlesize"] = 16
plt.rcParams["axes.titleweight"] = "bold"
plt.rcParams["axes.labelsize"] = 14
plt.rcParams["axes.labelpad"] = 12

# Load dataset
ipo_df = pd.read_csv("Indian_IPO_Market_Data.csv")

# 1. Display the first five and last five rows
print("===== First 5 Rows =====")
display(ipo_df.head())

print("\n===== Last 5 Rows =====")
display(ipo_df.tail())

# 2. Number of observations (rows) and variables (columns)
print("\n===== Shape of the Dataset =====")
print(f"Observations: {ipo_df.shape[0]}")
print(f"Variables: {ipo_df.shape[1]}")

# 3. Variable types (info)
print("\n===== Data Types & Non-Null Counts =====")
ipo_df.info()

# 4. Key statistics (describe, transposed)
print("\n===== Descriptive Statistics =====")
display(ipo_df.describe(include='all').T)
# Out:
# ===== First 5 Rows =====
#       Date           IPOName  Issue_Size  Subscription_QIB  Subscription_HNI  \
# 0  03/02/10    Infinite Comp     189.800            48.440           106.020
# 1  08/02/10    Jubilant Food     328.700            59.390            51.950
# 2  15/02/10    Syncom Health      56.250             0.990            16.600
# 3  15/02/10  Vascon Engineer     199.800             1.120             3.650
# 4  19/02/10      Thangamayil       0.000             0.520             1.520
#
#    Subscription_RII  Subscription_Total  Issue_Price  Listing_Gains_Percent
# 0            11.080              43.220          165                 11.820
# 1             3.790              31.110          145                -84.210
# 2             6.250               5.170           75                 17.130
# 3             0.620               1.220          165                -11.280
# 4             2.260               1.120           75                 -5.200
# ===== Last 5 Rows =====
#         Date           IPOName  Issue_Size  Subscription_QIB  \
# 314  26/08/22        Syrma SGS     840.130            42.420
# 315  06/09/22  Dreamfolks Serv     562.100            27.480
# 316  15/09/22              TMB     792.000             0.510
# 317  26/09/22  Harsha Engineer     755.000           113.820
# 318  17/10/22  Electronics Mar     500.000            58.810
#
#      Subscription_HNI  Subscription_RII  Subscription_Total  Issue_Price  \
# 314             7.130             2.840              15.590          220
# 315            14.180            24.190              23.250          326
# 316             1.770             3.440               1.390          525
# 317            40.360            12.440              47.190          330
# 318            15.390             8.270              24.230           59
#
#      Listing_Gains_Percent
# 314                 42.300
# 315                 41.920
# 316                 -3.150
# 317                 47.240
# 318                 43.140
# ===== Shape of the Dataset =====
# Observations: 319
# Variables: 9
#
# ===== Data Types & Non-Null Counts =====
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319 entries, 0 to 318
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Date                   319 non-null    object
#  1   IPOName                319 non-null    object
#  2   Issue_Size             319 non-null    float64
#  3   Subscription_QIB       319 non-null    float64
#  4   Subscription_HNI       319 non-null    float64
#  5   Subscription_RII       319 non-null    float64
#  6   Subscription_Total     319 non-null    float64
#  7   Issue_Price            319 non-null    int64
#  8   Listing_Gains_Percent  319 non-null    float64
# dtypes: float64(6), int64(1), object(2)
# memory usage: 22.6+ KB
#
# ===== Descriptive Statistics =====
#                         count unique            top freq      mean       std  \
# Date                      319    287       16/08/21    4       NaN       NaN
# IPOName                   319    319  Infinite Comp    1       NaN       NaN
# Issue_Size            319.000    NaN            NaN  NaN 1,192.860 2,384.644
# Subscription_QIB      319.000    NaN            NaN  NaN    25.684    40.717
# Subscription_HNI      319.000    NaN            NaN  NaN    70.091   142.454
# Subscription_RII      319.000    NaN            NaN  NaN     8.562    14.509
# Subscription_Total    319.000    NaN            NaN  NaN    27.447    48.772
# Issue_Price           319.000    NaN            NaN  NaN   375.129   353.898
# Listing_Gains_Percent 319.000    NaN            NaN  NaN     4.743    47.651
#
#                           min     25%     50%       75%        max
# Date                      NaN     NaN     NaN       NaN        NaN
# IPOName                   NaN     NaN     NaN       NaN        NaN
# Issue_Size              0.000 169.005 496.250 1,100.000 21,000.000
# Subscription_QIB        0.000   1.150   4.940    34.635    215.450
# Subscription_HNI        0.000   1.255   5.070    62.095    958.070
# Subscription_RII        0.000   1.275   3.420     8.605    119.440
# Subscription_Total      0.000   1.645   4.930    33.395    326.490
# Issue_Price             0.000 119.000 250.000   536.000  2,150.000
# Listing_Gains_Percent -97.150 -11.555   1.810    25.310    270.400

# %% [markdown]
# ## Dataset Overview
# ---
# The dataset consists of information on **319 IPOs** in the Indian market, covering issue sizes, subscription details across different investor categories, issue prices, and the corresponding listing gains. It contains **9 variables** in total, with 7 numerical features and 2 categorical features.
#
# ### Sample Records
# The first five and last five rows of the dataset provide a snapshot of the data:
#
# - **First 5 Rows** include IPOs such as *Infinite Comp*, *Jubilant Food*, *Syncom Health*, *Vascon Engineer*, and *Thangamayil* from 2010.
# - **Last 5 Rows** include more recent IPOs like *Syrma SGS*, *Dreamfolks Serv*, *TMB*, *Harsha Engineer*, and *Electronics Mar* from 2022.
#
# This indicates that the dataset spans more than a decade of IPO activity.
#
# ### Dataset Shape
# - **Observations (rows):** 319
# - **Variables (columns):** 9
#
# ### Variable Types
# - **Categorical Variables:** `Date`, `IPOName`
# - **Numerical Variables:** `Issue_Size`, `Subscription_QIB`, `Subscription_HNI`, `Subscription_RII`, `Subscription_Total`, `Issue_Price`, `Listing_Gains_Percent`
#
# ### Descriptive Statistics
# Key insights from the numerical features:
# - **Issue Size:** Ranges from *0* to *21,000 crores*, with a mean around *1,193 crores*. The large standard deviation indicates high variability between IPO sizes.
# - **Subscription Levels:**
#   - QIB subscriptions average *25.7x* with a maximum of *215x*.
#   - HNI subscriptions show the highest variability, averaging *70x* but reaching as high as *958x*.
#   - RII subscriptions average *8.6x* with a maximum of *119x*.
#   - Total subscriptions average *27.4x*, but some IPOs were subscribed over *300x*.
# - **Issue Price:** Ranges from *₹0* (possibly missing or erroneous entries) to *₹2150*, with a mean around *₹375*.
# - **Listing Gains (%):** The average listing gain is around *4.7%*. However, the distribution is highly dispersed:
#   - Minimum: *-97.15%* (loss on listing)
#   - Median: *1.81%*
#   - Maximum: *270.4%*
#
# ### Observations
# - The dataset is complete with no missing values at this stage.
# - Categorical variables (`Date` and `IPOName`) are identifiers and may not add predictive power directly but can help in temporal or group-wise analysis.
# - Numerical features show strong variability, particularly in subscription levels and issue sizes, which are likely important predictors for listing gains.

# %% [markdown]
# ## Exploratory Data Analysis

# %%
# Duplicate values
duplicates = ipo_df.duplicated().sum()
print("===== Duplicate Values =====")
print(f"Number of duplicate rows: {duplicates}")

# Missing values
missing_percent = ipo_df.isnull().mean() * 100
print("\n===== Missing Values (in %) =====")
print(missing_percent)

# Outlier Detection (IQR method)
numeric_cols = ipo_df.select_dtypes(include=['float64','int64']).columns

outliers_summary = {}
for col in numeric_cols:
    Q1 = ipo_df[col].quantile(0.25)
    Q3 = ipo_df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = ipo_df[(ipo_df[col] < lower_bound) | (ipo_df[col] > upper_bound)][col].count()
    outliers_summary[col] = outliers

outliers_df = pd.DataFrame.from_dict(outliers_summary, orient='index', columns=['Outlier_Count'])
print("\n===== Outliers per Numerical Column =====")
display(outliers_df)
# Out:
# ===== Duplicate Values =====
# Number of duplicate rows: 0
#
# ===== Missing Values (in %) =====
# Date                    0.000
# IPOName                 0.000
# Issue_Size              0.000
# Subscription_QIB        0.000
# Subscription_HNI        0.000
# Subscription_RII        0.000
# Subscription_Total      0.000
# Issue_Price             0.000
# Listing_Gains_Percent   0.000
# dtype: float64
#
# ===== Outliers per Numerical Column =====
#                        Outlier_Count
# Issue_Size                        34
# Subscription_QIB                  35
# Subscription_HNI                  48
# Subscription_RII                  33
# Subscription_Total                31
# Issue_Price                       12
# Listing_Gains_Percent             46

# %% [markdown]
# ## Data Quality and Outlier Analysis
# ---
# ### Duplicate Values
# - The dataset contains **0 duplicate rows**, confirming that all records are unique.
#
# ### Missing Values
# - There are **no missing values** across any of the 9 variables.
# - This ensures that the dataset is complete and does not require imputation for missing data.
#
# ### Outlier Detection
# - Outliers were identified using the **Interquartile Range (IQR) method** for each numerical column:
# - Outliers are present in **all numerical features**, with the highest counts in `Subscription_HNI` (48) and `Listing_Gains_Percent` (46).
# - These outliers likely represent extreme IPO events, such as heavily oversubscribed offerings or unusually high listing gains.
# - Since IPO data is inherently volatile, some of these outliers may carry **meaningful information** rather than being errors.

# %%
# Boxplots for numerical columns
plt.figure(figsize=(16, 16))

for i, col in enumerate(numeric_cols, 1):
    plt.subplot(3, 3, i)
    sns.boxplot(y=ipo_df[col], color="#82FF9E", width=.2)
    plt.title(f"Boxplot of {col}")
    plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Distribution of Numerical Features
# ---
# Boxplots were generated for all 7 numerical variables in the dataset to assess the spread of the data and identify potential outliers.
#
# ### Key Insights
# - **Issue_Size:** Most IPOs have relatively small to mid-sized issues, but a few reach extremely large values (above ₹15,000 crores). The long tail highlights the presence of very large offerings compared to the majority.
# - **Subscription_QIB, Subscription_HNI, Subscription_RII, Subscription_Total:**
#   - All four subscription-related variables exhibit **strong right skewness** with numerous outliers.
#   - A small number of IPOs were subscribed at exceptionally high levels (e.g., QIB over 200x, HNI close to 1,000x).
#   - These outliers reflect blockbuster IPOs that generated extraordinary investor demand.
# - **Issue_Price:** The majority of IPOs are priced below ₹600, though some extend beyond ₹2,000. The presence of outliers suggests premium-priced IPOs exist in the dataset.
# - **Listing_Gains_Percent:** The distribution is highly variable. While most IPOs show modest gains or losses around the median (~2%), several IPOs experienced **very high positive gains (above 200%)** or significant losses (close to -100%).
#
# ### Observations
# - The **heavy right skew** in issue size and subscription levels is expected in IPO data, as a handful of offerings attract disproportionate investor interest.
# - Outliers in `Listing_Gains_Percent` are particularly important, as they represent extreme outcomes for investors — both spectacular gains and steep losses.
# - These patterns suggest that normalization or transformation of some variables may be beneficial before modeling, but the extreme cases may also provide **critical signals** for predicting listing gains.

# %%
# Correlation Heatmap
corr_matrix = ipo_df[numeric_cols].corr()

plt.figure(figsize=(12, 12))
sns.heatmap(
    corr_matrix, 
    annot=True, fmt=".3f", cmap=sns.cubehelix_palette(as_cmap=True), 
    cbar=False, square=True, linewidths=0
)
plt.title("Correlation Heatmap of Numeric Features", pad=15)
plt.show()

# %% [markdown]
# ## Correlation Analysis
# ---
# The correlation heatmap highlights the relationships between the numerical variables in the dataset.
#
# ### Key Insights
# - **Subscription Variables:**
#   - `Subscription_Total` is highly correlated with both `Subscription_HNI` (**0.955**) and `Subscription_QIB` (**0.816**).
#   - Strong correlations also exist between `Subscription_HNI` and `Subscription_QIB` (**0.774**) and between `Subscription_HNI` and `Subscription_RII` (**0.623**).
#   - These results confirm that total subscription demand is largely driven by institutional (QIB) and HNI investor participation, though retail investors (RII) also contribute meaningfully.
#
# - **Listing Gains (%):**
#   - Shows **moderate positive correlations** with all subscription categories:
#     - `Subscription_RII` (**0.425**)
#     - `Subscription_Total` (**0.411**)
#     - `Subscription_QIB` (**0.396**)
#     - `Subscription_HNI` (**0.375**)
#   - This indicates that **higher subscription demand across investor categories is generally associated with higher listing gains**.
#   - However, no single feature exhibits an extremely strong correlation, suggesting that listing gains are influenced by multiple interacting factors beyond subscription levels alone.
#
# - **Issue Size:**
#   - Weakly correlated with other variables, including `Listing_Gains_Percent` (**0.020**). Larger issue sizes do not necessarily translate into higher or lower listing gains.
#
# - **Issue Price:**
#   - Positively correlated with `Issue_Size` (**0.365**) but shows virtually no relationship with listing gains (**0.018**).
#   - This suggests that while higher-priced IPOs tend to be larger in size, **issue price itself is not a strong determinant of first-day performance**.
#
# ### Observations
# - Subscription data (QIB, HNI, RII, and Total) are key predictive indicators for listing gains.
# - Issue size and issue price are less influential in determining listing outcomes.
# - The moderate correlations suggest that a **multivariate approach** is well-suited to capture the interplay between features and predict listing gains.

# %% [markdown]
# ## Data Preprocessing and Feature Engineering

# %%
# Remove whitespace from column names
ipo_df.columns = ipo_df.columns.str.strip()

# Add binary target
ipo_df["Profit"] = (ipo_df["Listing_Gains_Percent"] > 0).astype(int)

# Parse date and extract year
ipo_df["Date_dt"] = pd.to_datetime(ipo_df["Date"], format="%d/%m/%y", dayfirst=True, errors="coerce")
ipo_df["Year"] = ipo_df["Date_dt"].dt.year

# Log-transform skewed non-negative features
log_cols = [
    "Issue_Size",
    "Subscription_QIB",
    "Subscription_HNI",
    "Subscription_RII",
    "Subscription_Total",
    "Issue_Price",
]
for c in log_cols:
    ipo_df[f"{c}_log"] = np.log1p(ipo_df[c].clip(lower=0))

# Drop non-predictive identifiers
ipo_df_final = ipo_df.drop(columns=["Date", "IPOName", "Date_dt"])

# Display the final result
ipo_df_final
# Out:
#      Issue_Size  Subscription_QIB  Subscription_HNI  Subscription_RII  \
# 0       189.800            48.440           106.020            11.080
# 1       328.700            59.390            51.950             3.790
# 2        56.250             0.990            16.600             6.250
# 3       199.800             1.120             3.650             0.620
# 4         0.000             0.520             1.520             2.260
# ..          ...               ...               ...               ...
# 314     840.130            42.420             7.130             2.840
# 315     562.100            27.480            14.180            24.190
# 316     792.000             0.510             1.770             3.440
# 317     755.000           113.820            40.360            12.440
# 318     500.000            58.810            15.390             8.270
#
#      Subscription_Total  Issue_Price  Listing_Gains_Percent  Profit  Year  \
# 0                43.220          165                 11.820       1  2010
# 1                31.110          145                -84.210       0  2010
# 2                 5.170           75                 17.130       1  2010
# 3                 1.220          165                -11.280       0  2010
# 4                 1.120           75                 -5.200       0  2010
# ..                  ...          ...                    ...     ...   ...
# 314              15.590          220                 42.300       1  2022
# 315              23.250          326                 41.920       1  2022
# 316               1.390          525                 -3.150       0  2022
# 317              47.190          330                 47.240       1  2022
# 318              24.230           59                 43.140       1  2022
#
#      Issue_Size_log  Subscription_QIB_log  Subscription_HNI_log  \
# 0             5.251                 3.901                 4.673
# 1             5.798                 4.101                 3.969
# 2             4.047                 0.688                 2.868
# 3             5.302                 0.751                 1.537
# 4             0.000                 0.419                 0.924
# ..              ...                   ...                   ...
# 314           6.735                 3.771                 2.096
# 315           6.333                 3.349                 2.720
# 316           6.676                 0.412                 1.019
# 317           6.628                 4.743                 3.722
# 318           6.217                 4.091                 2.797
#
#      Subscription_RII_log  Subscription_Total_log  Issue_Price_log
# 0                   2.492                   3.789            5.112
# 1                   1.567                   3.469            4.984
# 2                   1.981                   1.820            4.331
# 3                   0.482                   0.798            5.112
# 4                   1.182                   0.751            4.331
# ..                    ...                     ...              ...
# 314                 1.345                   2.809            5.398
# 315                 3.226                   3.188            5.790
# 316                 1.491                   0.871            6.265
# 317                 2.598                   3.875            5.802
# 318                 2.227                   3.228            4.094
#
# [319 rows x 15 columns]

# %% [markdown]
# ## Analysing the Data Preprocessing and Feature Engineering Steps
# ---
# ### 1. Cleaning Column Names
# - Leading and trailing whitespaces were removed from column names to ensure consistency when referencing variables.
#
# ### 2. Target Variable Creation
# - A new binary target variable **Profit** was created:
#   - **1** if **Listing_Gains_Percent > 0** (IPO closed with a profit on listing day).
#   - **0** otherwise (IPO closed at a loss or no gain).
# - This transformation reframed the problem as a **binary classification task**, which will be addressed using a deep learning model.
#
# ### 3. Date Feature Engineering
# - The `Date` column was converted to datetime format.
# - From it, the **`Year`** of listing was extracted, capturing potential macroeconomic and market-cycle effects.
# - Other time-based features (month, quarter) were not included to keep the feature space simpler and avoid unnecessary noise.
#
# ### 4. Log Transformation of Skewed Features
# - Several numerical features showed heavy right skewness and extreme outliers:
#   - `Issue_Size`, `Subscription_QIB`, `Subscription_HNI`, `Subscription_RII`, `Subscription_Total`, `Issue_Price`
# - These were **log-transformed using `log1p`** to reduce skewness, compress extreme values, and stabilize variance.
# - The transformed versions were added as new features with `_log` suffix.
#
# ### 5. Dropping Non-Predictive Identifiers
# - `Date`, `IPOName`, and the intermediate `Date_dt` column were dropped, as they are identifiers and do not directly contribute to prediction after feature extraction.

# %% [markdown]
# ## Feature Selection

# %%
# Build feature set (exclude leakage from Listing_Gains_Percent)
feature_cols = [f"{c}_log" for c in log_cols] + ["Year"]
target_col = "Profit"

X = ipo_df_final[feature_cols].copy()
y = ipo_df_final[target_col].copy()

# Scale numerical features
scaler = StandardScaler()
X_scaled = pd.DataFrame(
    scaler.fit_transform(X),
    columns=feature_cols,
    index=X.index
)

# Display the Selected Features
X_scaled
# Out:
#      Issue_Size_log  Subscription_QIB_log  Subscription_HNI_log  \
# 0            -0.535                 1.128                 1.124
# 1            -0.176                 1.256                 0.766
# 2            -1.325                -0.930                 0.205
# 3            -0.501                -0.889                -0.473
# 4            -3.983                -1.102                -0.785
# ..              ...                   ...                   ...
# 314           0.439                 1.045                -0.188
# 315           0.176                 0.775                 0.130
# 316           0.400                -1.107                -0.737
# 317           0.369                 1.668                 0.640
# 318           0.099                 1.250                 0.169
#
#      Subscription_RII_log  Subscription_Total_log  Issue_Price_log   Year
# 0                   0.822                   1.061           -0.321 -1.370
# 1                  -0.067                   0.843           -0.439 -1.370
# 2                   0.331                  -0.280           -1.037 -1.370
# 3                  -1.109                  -0.976           -0.321 -1.370
# 4                  -0.437                  -1.008           -1.037 -1.370
# ..                    ...                     ...              ...    ...
# 314                -0.279                   0.393           -0.059  1.399
# 315                 1.529                   0.652            0.300  1.399
# 316                -0.140                  -0.926            0.736  1.399
# 317                 0.925                   1.119            0.311  1.399
# 318                 0.568                   0.679           -1.253  1.399
#
# [319 rows x 7 columns]

# %% [markdown]
# ## Feature Set and Scaling
# ---
# - The final feature set included:
#   - Log-transformed subscription and size-related features.
#   - `Year` as a numeric time-based feature.
# - The target variable was **`Profit`**.
# - Features were standardized using **`StandardScaler`** to have mean = 0 and standard deviation = 1, ensuring comparable scales across all inputs.
# - Scaling benefits deep learning models by improving gradient-based optimization and convergence stability.

# %% [markdown]
# ## Bulding a Deep Learning Model

# %%
# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y,
    test_size=0.2,     # 20% for testing
    random_state=42,   # reproducibility
    stratify=y         # preserves class balance in both sets
)

print(f"Train set: {X_train.shape[0]} rows")
print(f"Test set:  {X_test.shape[0]} rows")

# Check class balance
train_balance = y_train.value_counts(normalize=True).rename("proportion_train")
test_balance = y_test.value_counts(normalize=True).rename("proportion_test")

balance_df = pd.concat([train_balance, test_balance], axis=1)
print("\nClass balance (0 = No Profit, 1 = Profit):")
display(balance_df)
# Out:
# Train set: 255 rows
# Test set:  64 rows
#
# Class balance (0 = No Profit, 1 = Profit):
#         proportion_train  proportion_test
# Profit
# 1                  0.545            0.547
# 0                  0.455            0.453

# %%
SEED = 42
os.environ["PYTHONHASHSEED"] = str(SEED)            # stable Python hashing
tf.keras.utils.set_random_seed(SEED)                # seeds Python, NumPy, TF

try:
    tf.config.experimental.enable_op_determinism(True)  # deterministic TF ops
except Exception:
    pass
tf.keras.backend.clear_session()                    # fresh graph/session

def to_f32(a):
    import numpy as _np
    return _np.asarray(getattr(a, "values", a), dtype=_np.float32)

# Data
Xtr_np = to_f32(X_train)
ytr_np = to_f32(y_train).ravel()
Xte_np = to_f32(X_test)
yte_np = to_f32(y_test).ravel()

for name, arr in [("X_train", Xtr_np), ("y_train", ytr_np), ("X_test", Xte_np), ("y_test", yte_np)]:
    assert np.isfinite(arr).all(), f"{name} contains non-finite values"

sss = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=SEED)
(train_idx, val_idx), = sss.split(Xtr_np, ytr_np)
X_tr, X_val = Xtr_np[train_idx], Xtr_np[val_idx]
y_tr, y_val = ytr_np[train_idx], ytr_np[val_idx]

print(f"Train: {X_tr.shape}, Val: {X_val.shape}, Test: {Xte_np.shape}")
print(f"y_tr share of class 1: {y_tr.mean():.3f} | y_val: {y_val.mean():.3f} | y_test: {yte_np.mean():.3f}")

# Model
inp = Input(shape=(X_tr.shape[1],), name="inputs")
x = layers.Dense(16, activation="relu", kernel_regularizer=regularizers.l2(1e-4), name="dense_16")(inp)
x = layers.BatchNormalization(name="bn_1")(x)
x = layers.Dropout(0.2, name="dropout_1")(x)
x = layers.Dense(8, activation="relu", kernel_regularizer=regularizers.l2(1e-4), name="dense_8")(x)
x = layers.BatchNormalization(name="bn_2")(x)
x = layers.Dropout(0.2, name="dropout_2")(x)
out = layers.Dense(1, activation="sigmoid", name="output")(x)

model = Model(inputs=inp, outputs=out, name="ipo_functional_nn")
model.compile(
    optimizer="adam",
    loss="binary_crossentropy",
    metrics=["accuracy", AUC(name="auc"), Precision(name="precision"), Recall(name="recall")]
)

# Save initial weights so re-running this cell starts from the same point
_init_weights = model.get_weights()

# Training (deterministic)
es   = EarlyStopping(monitor="val_auc", mode="max", patience=20, restore_best_weights=True, verbose=1)
rlrp = ReduceLROnPlateau(monitor="val_auc", mode="max", factor=0.5, patience=10, min_lr=1e-5, verbose=1)

model.set_weights(_init_weights)  # identical start on re-runs
history = model.fit(
    X_tr, y_tr,
    validation_data=(X_val, y_val),
    epochs=500,
    batch_size=16,
    shuffle=False,                 # key for reproducibility
    callbacks=[es, rlrp],
    verbose=1
)

# Evaluation
val_proba  = model.predict(X_val,  verbose=0).ravel()
test_proba = model.predict(Xte_np, verbose=0).ravel()

roc_auc_val = roc_auc_score(y_val, val_proba)
prec, rec, thr = precision_recall_curve(y_val, val_proba)
pr_auc_val = auc(rec, prec)
print(f"Validation ROC-AUC: {roc_auc_val:.3f} | PR-AUC: {pr_auc_val:.3f}")

candidate_thr = np.linspace(0.05, 0.95, 91)
f1s = [f1_score(y_val, (val_proba >= t).astype(int)) for t in candidate_thr]
best_idx = int(np.argmax(f1s))
best_thr = float(candidate_thr[best_idx])
print(f"Best F1 on val: {f1s[best_idx]:.3f} at threshold = {best_thr:.2f}")

test_pred = (test_proba >= best_thr).astype(int)
print("\nTest set metrics @ best val F1 threshold:")
print("ROC-AUC:", roc_auc_score(yte_np, test_proba).round(3))
print(classification_report(yte_np, test_pred, digits=3))

cm = confusion_matrix(yte_np, test_pred)
print("Confusion Matrix:\n", cm)
# Out:
# Train: (204, 7), Val: (51, 7), Test: (64, 7)
# y_tr share of class 1: 0.544 | y_val: 0.549 | y_test: 0.547
# Epoch 1/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - accuracy: 0.5441 - auc: 0.5986 - loss: 0.9270 - precision: 0.5789 - recall: 0.5946 - val_accuracy: 0.5686 - val_auc: 0.5800 - val_loss: 0.7001 - val_precision: 0.6667 - val_recall: 0.4286 - learning_rate: 0.0010
# Epoch 2/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5343 - auc: 0.5631 - loss: 0.9802 - precision: 0.5769 - recall: 0.5405 - val_accuracy: 0.5686 - val_auc: 0.6180 - val_loss: 0.6880 - val_precision: 0.6364 - val_recall: 0.5000 - learning_rate: 0.0010
# Epoch 3/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5931 - auc: 0.6162 - loss: 0.8560 - precision: 0.6373 - recall: 0.5856 - val_accuracy: 0.5686 - val_auc: 0.6421 - val_loss: 0.6764 - val_precision: 0.6250 - val_recall: 0.5357 - learning_rate: 0.0010
# Epoch 4/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6373 - auc: 0.6866 - loss: 0.7689 - precision: 0.6729 - recall: 0.6486 - val_accuracy: 0.6275 - val_auc: 0.6661 - val_loss: 0.6670 - val_precision: 0.6667 - val_recall: 0.6429 - learning_rate: 0.0010
# Epoch 5/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6275 - auc: 0.6799 - loss: 0.7521 - precision: 0.6667 - recall: 0.6306 - val_accuracy: 0.6471 - val_auc: 0.6809 - val_loss: 0.6603 - val_precision: 0.6667 - val_recall: 0.7143 - learning_rate: 0.0010
# Epoch 6/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6373 - auc: 0.7028 - loss: 0.6954 - precision: 0.6796 - recall: 0.6306 - val_accuracy: 0.6275 - val_auc: 0.6863 - val_loss: 0.6549 - val_precision: 0.6452 - val_recall: 0.7143 - learning_rate: 0.0010
# Epoch 7/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5980 - auc: 0.6750 - loss: 0.7108 - precision: 0.6381 - recall: 0.6036 - val_accuracy: 0.6471 - val_auc: 0.6941 - val_loss: 0.6507 - val_precision: 0.6562 - val_recall: 0.7500 - learning_rate: 0.0010
# Epoch 8/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6618 - auc: 0.7077 - loss: 0.6685 - precision: 0.7019 - recall: 0.6577 - val_accuracy: 0.6275 - val_auc: 0.7065 - val_loss: 0.6455 - val_precision: 0.6452 - val_recall: 0.7143 - learning_rate: 0.0010
# Epoch 9/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6667 - auc: 0.6921 - loss: 0.7256 - precision: 0.6870 - recall: 0.7117 - val_accuracy: 0.6471 - val_auc: 0.7081 - val_loss: 0.6419 - val_precision: 0.6667 - val_recall: 0.7143 - learning_rate: 0.0010
# Epoch 10/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6618 - auc: 0.7122 - loss: 0.6911 - precision: 0.6810 - recall: 0.7117 - val_accuracy: 0.6275 - val_auc: 0.7151 - val_loss: 0.6372 - val_precision: 0.6452 - val_recall: 0.7143 - learning_rate: 0.0010
# Epoch 11/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6176 - auc: 0.6533 - loss: 0.7279 - precision: 0.6514 - recall: 0.6396 - val_accuracy: 0.6471 - val_auc: 0.7166 - val_loss: 0.6324 - val_precision: 0.6562 - val_recall: 0.7500 - learning_rate: 0.0010
# Epoch 12/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6667 - auc: 0.7188 - loss: 0.6529 - precision: 0.7129 - recall: 0.6486 - val_accuracy: 0.6471 - val_auc: 0.7275 - val_loss: 0.6292 - val_precision: 0.6562 - val_recall: 0.7500 - learning_rate: 0.0010
# Epoch 13/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6373 - auc: 0.6588 - loss: 0.7466 - precision: 0.6555 - recall: 0.7027 - val_accuracy: 0.6667 - val_auc: 0.7345 - val_loss: 0.6261 - val_precision: 0.6774 - val_recall: 0.7500 - learning_rate: 0.0010
# Epoch 14/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6716 - auc: 0.7367 - loss: 0.6316 - precision: 0.7037 - recall: 0.6847 - val_accuracy: 0.6863 - val_auc: 0.7352 - val_loss: 0.6245 - val_precision: 0.7000 - val_recall: 0.7500 - learning_rate: 0.0010
# Epoch 15/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6569 - auc: 0.7001 - loss: 0.6701 - precision: 0.6847 - recall: 0.6847 - val_accuracy: 0.6667 - val_auc: 0.7360 - val_loss: 0.6215 - val_precision: 0.6774 - val_recall: 0.7500 - learning_rate: 0.0010
# Epoch 16/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6716 - auc: 0.7234 - loss: 0.6368 - precision: 0.6897 - recall: 0.7207 - val_accuracy: 0.6667 - val_auc: 0.7352 - val_loss: 0.6210 - val_precision: 0.6774 - val_recall: 0.7500 - learning_rate: 0.0010
# Epoch 17/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6618 - auc: 0.7015 - loss: 0.6853 - precision: 0.6750 - recall: 0.7297 - val_accuracy: 0.6667 - val_auc: 0.7337 - val_loss: 0.6222 - val_precision: 0.6774 - val_recall: 0.7500 - learning_rate: 0.0010
# Epoch 18/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6225 - auc: 0.6854 - loss: 0.6780 - precision: 0.6545 - recall: 0.6486 - val_accuracy: 0.6667 - val_auc: 0.7360 - val_loss: 0.6218 - val_precision: 0.6774 - val_recall: 0.7500 - learning_rate: 0.0010
# Epoch 19/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7157 - auc: 0.7663 - loss: 0.6021 - precision: 0.7265 - recall: 0.7658 - val_accuracy: 0.6863 - val_auc: 0.7352 - val_loss: 0.6214 - val_precision: 0.7000 - val_recall: 0.7500 - learning_rate: 0.0010
# Epoch 20/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6569 - auc: 0.7133 - loss: 0.6629 - precision: 0.6952 - recall: 0.6577 - val_accuracy: 0.7059 - val_auc: 0.7360 - val_loss: 0.6202 - val_precision: 0.7241 - val_recall: 0.7500 - learning_rate: 0.0010
# Epoch 21/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7059 - auc: 0.7352 - loss: 0.6268 - precision: 0.7217 - recall: 0.7477 - val_accuracy: 0.7059 - val_auc: 0.7360 - val_loss: 0.6208 - val_precision: 0.7241 - val_recall: 0.7500 - learning_rate: 0.0010
# Epoch 22/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6667 - auc: 0.7412 - loss: 0.6058 - precision: 0.6937 - recall: 0.6937 - val_accuracy: 0.7059 - val_auc: 0.7360 - val_loss: 0.6195 - val_precision: 0.7241 - val_recall: 0.7500 - learning_rate: 0.0010
# Epoch 23/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7402 - auc: 0.7581 - loss: 0.6040 - precision: 0.7500 - recall: 0.7838 - val_accuracy: 0.7059 - val_auc: 0.7329 - val_loss: 0.6190 - val_precision: 0.7241 - val_recall: 0.7500 - learning_rate: 0.0010
# Epoch 24/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7059 - auc: 0.7310 - loss: 0.6404 - precision: 0.7217 - recall: 0.7477 - val_accuracy: 0.7059 - val_auc: 0.7384 - val_loss: 0.6180 - val_precision: 0.7241 - val_recall: 0.7500 - learning_rate: 0.0010
# Epoch 25/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6814 - auc: 0.7402 - loss: 0.6254 - precision: 0.7130 - recall: 0.6937 - val_accuracy: 0.7059 - val_auc: 0.7399 - val_loss: 0.6159 - val_precision: 0.7241 - val_recall: 0.7500 - learning_rate: 0.0010
# Epoch 26/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6961 - auc: 0.7656 - loss: 0.5869 - precision: 0.7130 - recall: 0.7387 - val_accuracy: 0.7059 - val_auc: 0.7430 - val_loss: 0.6166 - val_precision: 0.7241 - val_recall: 0.7500 - learning_rate: 0.0010
# Epoch 27/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6912 - auc: 0.7708 - loss: 0.5748 - precision: 0.7034 - recall: 0.7477 - val_accuracy: 0.7059 - val_auc: 0.7422 - val_loss: 0.6181 - val_precision: 0.7241 - val_recall: 0.7500 - learning_rate: 0.0010
# Epoch 28/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6765 - auc: 0.7473 - loss: 0.6120 - precision: 0.6891 - recall: 0.7387 - val_accuracy: 0.7059 - val_auc: 0.7407 - val_loss: 0.6185 - val_precision: 0.7241 - val_recall: 0.7500 - learning_rate: 0.0010
# Epoch 29/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7010 - auc: 0.7525 - loss: 0.5997 - precision: 0.7049 - recall: 0.7748 - val_accuracy: 0.7059 - val_auc: 0.7384 - val_loss: 0.6184 - val_precision: 0.7241 - val_recall: 0.7500 - learning_rate: 0.0010
# Epoch 30/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6912 - auc: 0.7839 - loss: 0.5674 - precision: 0.7105 - recall: 0.7297 - val_accuracy: 0.6863 - val_auc: 0.7376 - val_loss: 0.6198 - val_precision: 0.7143 - val_recall: 0.7143 - learning_rate: 0.0010
# Epoch 31/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6471 - auc: 0.7534 - loss: 0.6024 - precision: 0.6726 - recall: 0.6847 - val_accuracy: 0.6863 - val_auc: 0.7329 - val_loss: 0.6218 - val_precision: 0.7143 - val_recall: 0.7143 - learning_rate: 0.0010
# Epoch 32/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6863 - auc: 0.7632 - loss: 0.5922 - precision: 0.7117 - recall: 0.7117 - val_accuracy: 0.6863 - val_auc: 0.7329 - val_loss: 0.6244 - val_precision: 0.7143 - val_recall: 0.7143 - learning_rate: 0.0010
# Epoch 33/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7157 - auc: 0.7780 - loss: 0.5653 - precision: 0.7477 - recall: 0.7207 - val_accuracy: 0.6863 - val_auc: 0.7345 - val_loss: 0.6252 - val_precision: 0.7143 - val_recall: 0.7143 - learning_rate: 0.0010
# Epoch 34/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7157 - auc: 0.7609 - loss: 0.5881 - precision: 0.7265 - recall: 0.7658 - val_accuracy: 0.6863 - val_auc: 0.7337 - val_loss: 0.6240 - val_precision: 0.7143 - val_recall: 0.7143 - learning_rate: 0.0010
# Epoch 35/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7059 - auc: 0.7877 - loss: 0.5547 - precision: 0.7107 - recall: 0.7748 - val_accuracy: 0.6863 - val_auc: 0.7306 - val_loss: 0.6279 - val_precision: 0.7143 - val_recall: 0.7143 - learning_rate: 0.0010
# Epoch 36/500
#  1/13 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.6250 - auc: 0.8492 - loss: 0.5787 - precision: 0.5455 - recall: 0.8571
# Epoch 36: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7304 - auc: 0.7786 - loss: 0.5696 - precision: 0.7500 - recall: 0.7568 - val_accuracy: 0.6863 - val_auc: 0.7298 - val_loss: 0.6311 - val_precision: 0.7143 - val_recall: 0.7143 - learning_rate: 0.0010
# Epoch 37/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7353 - auc: 0.7982 - loss: 0.5598 - precision: 0.7478 - recall: 0.7748 - val_accuracy: 0.6863 - val_auc: 0.7283 - val_loss: 0.6320 - val_precision: 0.7143 - val_recall: 0.7143 - learning_rate: 5.0000e-04
# Epoch 38/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6863 - auc: 0.7491 - loss: 0.6014 - precision: 0.7156 - recall: 0.7027 - val_accuracy: 0.7059 - val_auc: 0.7259 - val_loss: 0.6324 - val_precision: 0.7407 - val_recall: 0.7143 - learning_rate: 5.0000e-04
# Epoch 39/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7206 - auc: 0.7948 - loss: 0.5502 - precision: 0.7411 - recall: 0.7477 - val_accuracy: 0.7059 - val_auc: 0.7220 - val_loss: 0.6335 - val_precision: 0.7407 - val_recall: 0.7143 - learning_rate: 5.0000e-04
# Epoch 40/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6716 - auc: 0.7548 - loss: 0.5946 - precision: 0.6930 - recall: 0.7117 - val_accuracy: 0.7059 - val_auc: 0.7228 - val_loss: 0.6330 - val_precision: 0.7407 - val_recall: 0.7143 - learning_rate: 5.0000e-04
# Epoch 41/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6814 - auc: 0.7535 - loss: 0.6178 - precision: 0.7054 - recall: 0.7117 - val_accuracy: 0.7059 - val_auc: 0.7197 - val_loss: 0.6321 - val_precision: 0.7407 - val_recall: 0.7143 - learning_rate: 5.0000e-04
# Epoch 42/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7108 - auc: 0.7580 - loss: 0.6039 - precision: 0.7281 - recall: 0.7477 - val_accuracy: 0.7059 - val_auc: 0.7205 - val_loss: 0.6327 - val_precision: 0.7407 - val_recall: 0.7143 - learning_rate: 5.0000e-04
# Epoch 43/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6716 - auc: 0.7492 - loss: 0.6023 - precision: 0.6930 - recall: 0.7117 - val_accuracy: 0.7059 - val_auc: 0.7228 - val_loss: 0.6330 - val_precision: 0.7407 - val_recall: 0.7143 - learning_rate: 5.0000e-04
# Epoch 44/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6961 - auc: 0.7732 - loss: 0.5755 - precision: 0.7207 - recall: 0.7207 - val_accuracy: 0.7059 - val_auc: 0.7197 - val_loss: 0.6332 - val_precision: 0.7407 - val_recall: 0.7143 - learning_rate: 5.0000e-04
# Epoch 45/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6961 - auc: 0.7628 - loss: 0.5995 - precision: 0.7207 - recall: 0.7207 - val_accuracy: 0.7059 - val_auc: 0.7197 - val_loss: 0.6334 - val_precision: 0.7407 - val_recall: 0.7143 - learning_rate: 5.0000e-04
# Epoch 46/500
#  1/13 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.5625 - auc: 0.6032 - loss: 0.7377 - precision: 0.5000 - recall: 0.5714
# Epoch 46: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7010 - auc: 0.7601 - loss: 0.6004 - precision: 0.7451 - recall: 0.6847 - val_accuracy: 0.7059 - val_auc: 0.7197 - val_loss: 0.6343 - val_precision: 0.7407 - val_recall: 0.7143 - learning_rate: 5.0000e-04
# Epoch 46: early stopping
# Restoring model weights from the end of the best epoch: 26.
# Validation ROC-AUC: 0.744 | PR-AUC: 0.773
# Best F1 on val: 0.765 at threshold = 0.32
#
# Test set metrics @ best val F1 threshold:
# ROC-AUC: 0.725
#               precision    recall  f1-score   support
#
#          0.0      0.769     0.345     0.476        29
#          1.0      0.627     0.914     0.744        35
#
#     accuracy                          0.656        64
#    macro avg      0.698     0.630     0.610        64
# weighted avg      0.692     0.656     0.623        64
#
# Confusion Matrix:
#  [[10 19]
#  [ 3 32]]

# %% [markdown]
# ## Model Evaluation
# ---
# ### Setup & Data
# - **Model:** Small Keras MLP (7 inputs → [16] → [8] → 1, BN + Dropout, L2); ~**369** params.
# - **Splits:** Train **204**, Val **51**, Test **64** (stratified).
# - **Class share (Profit=1):** Train **0.544**, Val **0.549**, Test **0.547** — roughly balanced.
# - **Threshold selection:** Picked on validation by **max F1** → **t = 0.32** (Val F1 ≈ **0.765**).
#
# ### Headline Metrics
# - **Validation:** ROC-AUC ≈ **0.744**, PR-AUC ≈ **0.773**.
# - **Test (at t = 0.32):**
#   - **ROC-AUC:** **0.725** (ranking quality is decent).
#   - **Accuracy:** **0.656** (not the right KPI when threshold is misaligned).
#   - **Per-class (sklearn report):**
#     - Class **0** (No Profit): precision **0.769**, recall **0.345**, F1 **0.476** (support 29)
#     - Class **1** (Profit): precision **0.627**, recall **0.914**, F1 **0.744** (support 35)
#   - **Balanced accuracy:** ~**0.630**.
#   - **Confusion matrix:**
#
#     |              | Pred 0 | Pred 1 |
#     |--------------|:------:|:------:|
#     | **Actual 0** |  10    |  19    |
#     | **Actual 1** |   3    |  32    |
#
# ### What’s good
# - **Ranking ability is solid:** AUC around **0.72–0.74** on val/test shows the model **orders IPOs reasonably well** by profitability likelihood.
# - **High sensitivity to “Profit”:** At t=0.32, recall for class 1 is **0.914** — the model rarely misses a profitable IPO.
#
# ### What’s not ideal
# - **Too many false positives:** Specificity remains modest (**10/29** no-profit IPOs correctly rejected). The F1-optimized threshold (**0.32**) still **leans toward recall**, so the model predicts “Profit” on many borderline cases.
# - **Accuracy is misleading:** With that threshold, accuracy is **0.656** despite decent AUC; this is a **thresholding, not modeling, problem**.
# - **Small sample sizes:** With only **64** test cases, metric variance is non-trivial; tiny shifts in threshold can swing results.

# %%
# Plot ROC Curve
fpr, tpr, _ = roc_curve(y_val, val_proba)
plt.figure(figsize=(14,8))
plt.plot(fpr, tpr, label=f"ROC (AUC={roc_auc_val:.3f})")
plt.plot([0,1],[0,1], linestyle="--")
plt.xlabel("FPR")
plt.ylabel("TPR")
plt.title("Validation ROC")
plt.legend()
plt.show()

# %% [markdown]
# ## Validation ROC Analysis
# ---
# - **Purpose:** The ROC curve tells how well the model can **rank** profitable vs. non-profitable IPOs, independent of any single cutoff.
# - **Axes:**
#   - **X (FPR):** how often the model falsely flags a non-profit as “profit.”
#   - **Y (TPR/Recall):** how many true “profit” cases the model correctly catches.
# - **Diagonal dashed line:** a **coin flip**. Curves above it are better than random.
# - **Our curve (AUC ≈ 0.744):** On average, the model scores a random profitable IPO higher than a random non-profitable one about **74%** of the time.
# - **Shape matters:** The early, steep rise means you can capture many profitable IPOs while keeping false alarms relatively low—until you push for very high recall.
# - **How to use it:** Pick a point on the curve based on your tolerance for errors:
#   - Move **left** for **fewer false alarms** (but you’ll miss more winners).
#   - Move **up** for **more winners caught** (but you’ll flag more losers).
# - **Stair-steps:** The jagged look comes from a small validation set—normal, not a problem.

# %%
# Plot Precision–Recall Curve 
plt.figure(figsize=(14,8))
plt.plot(rec, prec, label=f"PR (AUC={pr_auc_val:.3f})")
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Validation Precision-Recall")
plt.legend()
plt.show()

# %% [markdown]
# ## Validation Precision–Recall Curve Analysis
# ---
#
# - **Purpose:** The PR curve focuses on performance when the **positive class** (profitable IPOs) is what you care most about.
# - **Axes:**
#   - **X (Recall):** “Of all the real winners, how many did we find?”
#   - **Y (Precision):** “Of the ones we predicted as winners, how many were actually winners?”
# - **Our curve (PR-AUC ≈ 0.773):** Across thresholds, the model keeps a **good balance** between finding winners and not flooding you with false alarms.
# - **Typical pattern:**
#   - At **low recall**, precision is very high (short, high-confidence list).
#   - As you push recall toward **0.7–1.0**, precision naturally drops because you’re casting a wider net and pulling in more false positives.
# - **How to use it:**
#   - Want a **shortlist with high confidence?** Choose a threshold that gives **high precision** (accept lower recall).
#   - Want to **catch most winners?** Choose a threshold with **high recall** (accept lower precision).
# - **Steps & jumps:** The curve’s jumps come from the small validation size and tied scores—expected behavior.

# %% [markdown]
# ## Conclusion
# ---
# I set out to rank and classify Indian IPOs for listing gains using a small, reproducible **TensorFlow Functional API** model, and to pick an operational threshold based on validation F1. The approach—stratified splits, compact MLP with BN/Dropout/L2, early stopping on AUC, and deterministic training—kept the pipeline simple and auditable.
#
# Results indicate the model captures meaningful signal for **ranking** (Test ROC-AUC **0.725**) and, at the F1-selected threshold (**0.32**), favors **high recall** for profitable IPOs (≈ **0.914**) with moderate precision (≈ **0.627**) and accuracy (≈ **0.656**). Given the small sample sizes, estimates have non-trivial variance; practical deployment should tune the threshold to business costs and may benefit from adding features, cross-validated training, and calibration or alternative models to improve precision without losing recall.
